# %% [markdown]
# # Lectura de datos (UNSW-NB15-V3):
#
# - Hay un total de 47 columnas para la selección de datos
# - Se quiere ver cuales son los features que van ayudar más al modelo y que features agregarle al modelo de deep learning

# %%
import pandas as pd
import numpy as np
import os

path = r'C:\Users\Felix\Desktop\Tesis\Datasets\Datasets_listos\UNSW-NB15-V3.parquet'

df = pd.read_parquet(path)
    
df.head()
# Out:
#       srcip     sport     dstip    dsport     proto     state           dur  \
# 0  0.023810  0.278431  0.043478  0.116915  0.000000  0.000000  1.361112e-05
# 1  0.119048  0.835752  0.021739  0.422812  0.000000  0.000000  7.404129e-05
# 2  0.190476  0.202777  0.130435  0.079194  0.000000  0.000000  9.081973e-07
# 3  0.309524  0.015915  0.239130  0.000809  0.007519  0.133333  5.690459e-10
# 4  0.309524  0.015915  0.239130  0.000809  0.007519  0.133333  5.690459e-10
#
#      sbytes    dbytes      sttl  ...  ct_flw_http_mthd  is_ftp_login  \
# 0  0.000317  0.004663  0.121569  ...          0.006516      0.009925
# 1  0.000622  0.000022  0.121569  ...          0.006516      0.009925
# 2  0.000150  0.000168  0.121569  ...          0.006516      0.009925
# 3  0.000018  0.000000  0.235294  ...          0.006516      0.009925
# 4  0.000018  0.000000  0.235294  ...          0.006516      0.009925
#
#    ct_srv_src  ct_srv_dst  ct_dst_ltm  ct_src_ ltm  ct_src_dport_ltm  \
# ...
